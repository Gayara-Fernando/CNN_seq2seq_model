# %%
# We will change the activation in the last layer of our final model from relu to linear to see if the plots are a little better and the result are better

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# 2025-07-16 10:29:28.842789: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-16 10:29:28.877549: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-07-16 10:29:28.877573: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-07-16 10:29:28.878376: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-16 10:29:28.884030: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# First import the train and validation data

X_train = np.load("data/train_input_sub_images/all_train_data.npy")
X_valid = np.load("data/valid_input_sub_images/all_valid_data.npy")

# %%
X_train.shape, X_valid.shape
# Out:
# ((3640, 13, 30, 30, 3), (910, 13, 30, 30, 3))

# %%
y_train = np.load("data/train_out_targets/all_train_targets.npy")
y_valid = np.load("data/valid_out_targets/all_valid_targets.npy")

# %%
y_train.shape, y_valid.shape
# Out:
# ((3640, 7, 32), (910, 7, 32))

# %%
# Let's redefine the model here

# %%
# We need our CNN model
CNN_model = tf.keras.models.load_model('../../Spring_2024/Bayes_for_comps/TS_bayes_implementation_for_TN/models/trained_gmp_model_dense_32_new.h5')
# Out:
# 2025-07-16 10:30:41.092755: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31134 MB memory:  -> device: 0, name: Tesla V100S-PCIE-32GB, pci bus id: 0000:06:00.0, compute capability: 7.0

# %%
# Define the reduced model

# last layer
output_reduced = CNN_model.layers[-11].output

reduced_model = tf.keras.models.Model(inputs = CNN_model.input, outputs = output_reduced)

reduced_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  conv2d (Conv2D)             (None, None, None, 32)    896
#
#  activation (Activation)     (None, None, None, 32)    0
#
#  conv2d_1 (Conv2D)           (None, None, None, 32)    9248
#
#  activation_1 (Activation)   (None, None, None, 32)    0
#
#  max_pooling2d (MaxPooling2  (None, None, None, 32)    0
#  D)
#
#  dropout (Dropout)           (None, None, None, 32)    0
#
#  conv2d_2 (Conv2D)           (None, None, None, 64)    18496
#
#  activation_2 (Activation)   (None, None, None, 64)    0
#
#  conv2d_3 (Conv2D)           (None, None, None, 64)    36928
#
#  activation_3 (Activation)   (None, None, None, 64)    0
#
#  max_pooling2d_1 (MaxPoolin  (None, None, None, 64)    0
#  g2D)
#
# =================================================================
# Total params: 65568 (256.12 KB)
# Trainable params: 36928 (144.25 KB)
# Non-trainable params: 28640 (111.88 KB)
# _________________________________________________________________

# %%
# okay, now need to add back the dropout, the dense and activation

# add dropout
added_dropout = tf.keras.layers.Dropout(0.5, name = "New_dropout_0")(CNN_model.layers[-11].output)

# add global max pooling
added_flatten = tf.keras.layers.GlobalMaxPooling2D()(added_dropout)

# add dense
added_dense = tf.keras.layers.Dense(64, name = "New_Dense_0")(added_flatten)

# add activation
added_Act = tf.keras.layers.Activation('relu', name = "New_Activation_0")(added_dense)

# add dropout
added_dropout2 = tf.keras.layers.Dropout(0.5, name = "New_dropout_1")(added_Act)

# # add another dense
added_dense_1 = tf.keras.layers.Dense(32, name = "New_Dense_1")(added_dropout2)

# # add activation
added_Act_1 = tf.keras.layers.Activation('relu', name = "New_Activation_1")(added_dense_1)

new_model = tf.keras.models.Model(CNN_model.input, added_Act_1)

# %%
new_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  conv2d (Conv2D)             (None, None, None, 32)    896
#
#  activation (Activation)     (None, None, None, 32)    0
#
#  conv2d_1 (Conv2D)           (None, None, None, 32)    9248
#
#  activation_1 (Activation)   (None, None, None, 32)    0
#
#  max_pooling2d (MaxPooling2  (None, None, None, 32)    0
#  D)
#
#  dropout (Dropout)           (None, None, None, 32)    0
#
#  conv2d_2 (Conv2D)           (None, None, None, 64)    18496
#
#  activation_2 (Activation)   (None, None, None, 64)    0
#
#  conv2d_3 (Conv2D)           (None, None, None, 64)    36928
#
#  activation_3 (Activation)   (None, None, None, 64)    0
#
#  max_pooling2d_1 (MaxPoolin  (None, None, None, 64)    0
#  g2D)
#
#  New_dropout_0 (Dropout)     (None, None, None, 64)    0
#
#  global_max_pooling2d (Glob  (None, 64)                0
#  alMaxPooling2D)
#
#  New_Dense_0 (Dense)         (None, 64)                4160
#
#  New_Activation_0 (Activati  (None, 64)                0
#  on)
#
#  New_dropout_1 (Dropout)     (None, 64)                0
#
#  New_Dense_1 (Dense)         (None, 32)                2080
#
#  New_Activation_1 (Activati  (None, 32)                0
#  on)
#
# =================================================================
# Total params: 71808 (280.50 KB)
# Trainable params: 43168 (168.62 KB)
# Non-trainable params: 28640 (111.88 KB)
# _________________________________________________________________

# %%
# Pass this thorugh the TD layer, and add the rest of the encoder decoder model for our exercise
input_time = 13
feature_size = 32
output_time = 7

# Encoder
# define encoder input
encoder_input = tf.keras.layers.Input(shape = (input_time, None, None, 3)) 

# pass the feature extractor model through a TD layer
td_model = tf.keras.layers.TimeDistributed(new_model)

td_out = td_model(encoder_input)

# add an lstm to process the input sequence
lstm_layer = tf.keras.layers.LSTM(64, activation = "relu", return_state = True, return_sequences = False)

encoder_outputs, state_h, state_c = lstm_layer(td_out)

# Decoder

# repeat the context vector 7 times
decoder_inp = tf.keras.layers.RepeatVector(output_time)(encoder_outputs)

# define an LSTM for the output sequence
decoder_lstm = tf.keras.layers.LSTM(64, return_sequences = True, activation = 'relu')

decoder_out = decoder_lstm(decoder_inp, initial_state = [state_h, state_c])

# TD dense layer to generate the output sequnces
dense_layer = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(feature_size))

dense_out = dense_layer(decoder_out)

# define the model
CNN_seq2seq_model = tf.keras.models.Model(inputs = encoder_input, outputs = dense_out)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
CNN_seq2seq_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 13, None, None, 3)   0         []
#                              ]
#
#  time_distributed (TimeDist  (None, 13, 32)               71808     ['input_1[0][0]']
#  ributed)
#
#  lstm (LSTM)                 [(None, 64),                 24832     ['time_distributed[0][0]']
#                               (None, 64),
#                               (None, 64)]
#
#  repeat_vector (RepeatVecto  (None, 7, 64)                0         ['lstm[0][0]']
#  r)
#
#  lstm_1 (LSTM)               (None, 7, 64)                33024     ['repeat_vector[0][0]',
#                                                                      'lstm[0][1]',
#                                                                      'lstm[0][2]']
#
#  time_distributed_1 (TimeDi  (None, 7, 32)                2080      ['lstm_1[0][0]']
#  stributed)
#
# ==================================================================================================
# Total params: 131744 (514.62 KB)
# Trainable params: 103104 (402.75 KB)
# Non-trainable params: 28640 (111.88 KB)
# __________________________________________________________________________________________________

# %%
# now, we can freeze the laeyr weights of the CNN model (the CNN layers at least)

# freeze the layers
for layer in CNN_model.layers:
    layer.trainable = False

# %%
# Final model before unfreezing - verify the required weights are frozen?
CNN_seq2seq_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 13, None, None, 3)   0         []
#                              ]
#
#  time_distributed (TimeDist  (None, 13, 32)               71808     ['input_1[0][0]']
#  ributed)
#
#  lstm (LSTM)                 [(None, 64),                 24832     ['time_distributed[0][0]']
#                               (None, 64),
#                               (None, 64)]
#
#  repeat_vector (RepeatVecto  (None, 7, 64)                0         ['lstm[0][0]']
#  r)
#
#  lstm_1 (LSTM)               (None, 7, 64)                33024     ['repeat_vector[0][0]',
#                                                                      'lstm[0][1]',
#                                                                      'lstm[0][2]']
#
#  time_distributed_1 (TimeDi  (None, 7, 32)                2080      ['lstm_1[0][0]']
#  stributed)
#
# ==================================================================================================
# Total params: 131744 (514.62 KB)
# Trainable params: 66176 (258.50 KB)
# Non-trainable params: 65568 (256.12 KB)
# __________________________________________________________________________________________________

# %%
# Okay, now let's train the frozen model

# compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
CNN_seq2seq_model.compile(loss='mean_squared_error', optimizer=opt, metrics = ['mean_absolute_error'])

# %%
# add early stopping
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', restore_best_weights = True, verbose=1, patience=10)

# %%
# %%time
# Train the model - Maybe we do not need a generator for now, let's see
history = CNN_seq2seq_model.fit(X_train, y_train, validation_data = (X_valid, y_valid), epochs = 100, callbacks = [es])
# Out:
# Epoch 1/100
# 2025-07-16 10:30:44.771672: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_2/time_distributed/model_1/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2025-07-16 10:30:45.212365: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2025-07-16 10:30:47.204594: I external/local_xla/xla/service/service.cc:168] XLA service 0x14f93cc91090 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-07-16 10:30:47.204640: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100S-PCIE-32GB, Compute Capability 7.0
# 2025-07-16 10:30:47.263390: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752679847.423227  709312 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 114/114 [==============================] - 10s 41ms/step - loss: 0.4813 - mean_absolute_error: 0.3676 - val_loss: 0.4233 - val_mean_absolute_error: 0.3462
# Epoch 2/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1846 - mean_absolute_error: 0.2530 - val_loss: 0.3143 - val_mean_absolute_error: 0.2876
# Epoch 3/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.1147 - mean_absolute_error: 0.1878 - val_loss: 0.2820 - val_mean_absolute_error: 0.2728
# Epoch 4/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.1088 - mean_absolute_error: 0.1775 - val_loss: 0.2699 - val_mean_absolute_error: 0.2656
# Epoch 5/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1064 - mean_absolute_error: 0.1731 - val_loss: 0.2490 - val_mean_absolute_error: 0.2542
# Epoch 6/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.1057 - mean_absolute_error: 0.1705 - val_loss: 0.2380 - val_mean_absolute_error: 0.2468
# Epoch 7/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.1049 - mean_absolute_error: 0.1685 - val_loss: 0.2304 - val_mean_absolute_error: 0.2428
# Epoch 8/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.1035 - mean_absolute_error: 0.1665 - val_loss: 0.2140 - val_mean_absolute_error: 0.2336
# Epoch 9/100
# 114/114 [==============================] - 4s 36ms/step - loss: 0.1032 - mean_absolute_error: 0.1654 - val_loss: 0.2141 - val_mean_absolute_error: 0.2326
# Epoch 10/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.1024 - mean_absolute_error: 0.1639 - val_loss: 0.2136 - val_mean_absolute_error: 0.2321
# Epoch 11/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1016 - mean_absolute_error: 0.1625 - val_loss: 0.2107 - val_mean_absolute_error: 0.2298
# Epoch 12/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.1016 - mean_absolute_error: 0.1620 - val_loss: 0.2010 - val_mean_absolute_error: 0.2245
# Epoch 13/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.1011 - mean_absolute_error: 0.1611 - val_loss: 0.2047 - val_mean_absolute_error: 0.2261
# Epoch 14/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.1014 - mean_absolute_error: 0.1618 - val_loss: 0.1933 - val_mean_absolute_error: 0.2203
# Epoch 15/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.1007 - mean_absolute_error: 0.1603 - val_loss: 0.2022 - val_mean_absolute_error: 0.2241
# Epoch 16/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.1009 - mean_absolute_error: 0.1606 - val_loss: 0.1839 - val_mean_absolute_error: 0.2152
# Epoch 17/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.1006 - mean_absolute_error: 0.1597 - val_loss: 0.1901 - val_mean_absolute_error: 0.2180
# Epoch 18/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1002 - mean_absolute_error: 0.1592 - val_loss: 0.1812 - val_mean_absolute_error: 0.2127
# Epoch 19/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1002 - mean_absolute_error: 0.1589 - val_loss: 0.1806 - val_mean_absolute_error: 0.2128
# Epoch 20/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1001 - mean_absolute_error: 0.1592 - val_loss: 0.1765 - val_mean_absolute_error: 0.2105
# Epoch 21/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0999 - mean_absolute_error: 0.1585 - val_loss: 0.1791 - val_mean_absolute_error: 0.2111
# Epoch 22/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0993 - mean_absolute_error: 0.1575 - val_loss: 0.1758 - val_mean_absolute_error: 0.2098
# Epoch 23/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0993 - mean_absolute_error: 0.1577 - val_loss: 0.1764 - val_mean_absolute_error: 0.2094
# Epoch 24/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0993 - mean_absolute_error: 0.1576 - val_loss: 0.1694 - val_mean_absolute_error: 0.2056
# Epoch 25/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0993 - mean_absolute_error: 0.1573 - val_loss: 0.1664 - val_mean_absolute_error: 0.2042
# Epoch 26/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0993 - mean_absolute_error: 0.1573 - val_loss: 0.1636 - val_mean_absolute_error: 0.2029
# Epoch 27/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0989 - mean_absolute_error: 0.1568 - val_loss: 0.1626 - val_mean_absolute_error: 0.2021
# Epoch 28/100
# 114/114 [==============================] - 4s 36ms/step - loss: 0.0989 - mean_absolute_error: 0.1566 - val_loss: 0.1689 - val_mean_absolute_error: 0.2056
# Epoch 29/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0989 - mean_absolute_error: 0.1565 - val_loss: 0.1630 - val_mean_absolute_error: 0.2021
# Epoch 30/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0990 - mean_absolute_error: 0.1568 - val_loss: 0.1692 - val_mean_absolute_error: 0.2056
# Epoch 31/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0988 - mean_absolute_error: 0.1566 - val_loss: 0.1642 - val_mean_absolute_error: 0.2025
# Epoch 32/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0983 - mean_absolute_error: 0.1558 - val_loss: 0.1599 - val_mean_absolute_error: 0.2008
# Epoch 33/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0983 - mean_absolute_error: 0.1558 - val_loss: 0.1587 - val_mean_absolute_error: 0.1998
# Epoch 34/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0983 - mean_absolute_error: 0.1556 - val_loss: 0.1572 - val_mean_absolute_error: 0.1993
# Epoch 35/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0984 - mean_absolute_error: 0.1557 - val_loss: 0.1600 - val_mean_absolute_error: 0.2018
# Epoch 36/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0981 - mean_absolute_error: 0.1554 - val_loss: 0.1493 - val_mean_absolute_error: 0.1944
# Epoch 37/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0979 - mean_absolute_error: 0.1548 - val_loss: 0.1514 - val_mean_absolute_error: 0.1956
# Epoch 38/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0984 - mean_absolute_error: 0.1555 - val_loss: 0.1606 - val_mean_absolute_error: 0.2008
# Epoch 39/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0980 - mean_absolute_error: 0.1548 - val_loss: 0.1558 - val_mean_absolute_error: 0.1978
# Epoch 40/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0975 - mean_absolute_error: 0.1542 - val_loss: 0.1562 - val_mean_absolute_error: 0.1984
# Epoch 41/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0980 - mean_absolute_error: 0.1545 - val_loss: 0.1538 - val_mean_absolute_error: 0.1968
# Epoch 42/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0978 - mean_absolute_error: 0.1544 - val_loss: 0.1534 - val_mean_absolute_error: 0.1969
# Epoch 43/100
# 114/114 [==============================] - 4s 36ms/step - loss: 0.0976 - mean_absolute_error: 0.1545 - val_loss: 0.1518 - val_mean_absolute_error: 0.1957
# Epoch 44/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0977 - mean_absolute_error: 0.1544 - val_loss: 0.1505 - val_mean_absolute_error: 0.1947
# Epoch 45/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0976 - mean_absolute_error: 0.1542 - val_loss: 0.1573 - val_mean_absolute_error: 0.1985
# Epoch 46/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0978 - mean_absolute_error: 0.1541 - val_loss: 0.1489 - val_mean_absolute_error: 0.1942
# Epoch 47/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0976 - mean_absolute_error: 0.1540 - val_loss: 0.1457 - val_mean_absolute_error: 0.1921
# Epoch 48/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0978 - mean_absolute_error: 0.1542 - val_loss: 0.1473 - val_mean_absolute_error: 0.1926
# Epoch 49/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0973 - mean_absolute_error: 0.1535 - val_loss: 0.1443 - val_mean_absolute_error: 0.1908
# Epoch 50/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0974 - mean_absolute_error: 0.1536 - val_loss: 0.1477 - val_mean_absolute_error: 0.1928
# Epoch 51/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0974 - mean_absolute_error: 0.1534 - val_loss: 0.1500 - val_mean_absolute_error: 0.1949
# Epoch 52/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0975 - mean_absolute_error: 0.1539 - val_loss: 0.1461 - val_mean_absolute_error: 0.1914
# Epoch 53/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0970 - mean_absolute_error: 0.1527 - val_loss: 0.1520 - val_mean_absolute_error: 0.1949
# Epoch 54/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0970 - mean_absolute_error: 0.1527 - val_loss: 0.1497 - val_mean_absolute_error: 0.1937
# Epoch 55/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0972 - mean_absolute_error: 0.1529 - val_loss: 0.1442 - val_mean_absolute_error: 0.1900
# Epoch 56/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0971 - mean_absolute_error: 0.1528 - val_loss: 0.1477 - val_mean_absolute_error: 0.1923
# Epoch 57/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0971 - mean_absolute_error: 0.1528 - val_loss: 0.1472 - val_mean_absolute_error: 0.1921
# Epoch 58/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0969 - mean_absolute_error: 0.1525 - val_loss: 0.1455 - val_mean_absolute_error: 0.1913
# Epoch 59/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0969 - mean_absolute_error: 0.1528 - val_loss: 0.1413 - val_mean_absolute_error: 0.1885
# Epoch 60/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0971 - mean_absolute_error: 0.1525 - val_loss: 0.1519 - val_mean_absolute_error: 0.1951
# Epoch 61/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0968 - mean_absolute_error: 0.1525 - val_loss: 0.1465 - val_mean_absolute_error: 0.1913
# Epoch 62/100
# 114/114 [==============================] - 4s 36ms/step - loss: 0.0972 - mean_absolute_error: 0.1532 - val_loss: 0.1494 - val_mean_absolute_error: 0.1934
# Epoch 63/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0969 - mean_absolute_error: 0.1526 - val_loss: 0.1425 - val_mean_absolute_error: 0.1892
# Epoch 64/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0972 - mean_absolute_error: 0.1531 - val_loss: 0.1465 - val_mean_absolute_error: 0.1912
# Epoch 65/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0968 - mean_absolute_error: 0.1523 - val_loss: 0.1530 - val_mean_absolute_error: 0.1955
# Epoch 66/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0970 - mean_absolute_error: 0.1526 - val_loss: 0.1432 - val_mean_absolute_error: 0.1890
# Epoch 67/100
# 114/114 [==============================] - 4s 36ms/step - loss: 0.0969 - mean_absolute_error: 0.1524 - val_loss: 0.1447 - val_mean_absolute_error: 0.1904
# Epoch 68/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0966 - mean_absolute_error: 0.1518 - val_loss: 0.1345 - val_mean_absolute_error: 0.1843
# Epoch 69/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0965 - mean_absolute_error: 0.1520 - val_loss: 0.1489 - val_mean_absolute_error: 0.1928
# Epoch 70/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0968 - mean_absolute_error: 0.1520 - val_loss: 0.1399 - val_mean_absolute_error: 0.1874
# Epoch 71/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0968 - mean_absolute_error: 0.1520 - val_loss: 0.1439 - val_mean_absolute_error: 0.1901
# Epoch 72/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0965 - mean_absolute_error: 0.1517 - val_loss: 0.1425 - val_mean_absolute_error: 0.1889
# Epoch 73/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0968 - mean_absolute_error: 0.1519 - val_loss: 0.1389 - val_mean_absolute_error: 0.1870
# Epoch 74/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0966 - mean_absolute_error: 0.1517 - val_loss: 0.1407 - val_mean_absolute_error: 0.1877
# Epoch 75/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0965 - mean_absolute_error: 0.1515 - val_loss: 0.1393 - val_mean_absolute_error: 0.1871
# Epoch 76/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0961 - mean_absolute_error: 0.1513 - val_loss: 0.1411 - val_mean_absolute_error: 0.1882
# Epoch 77/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0965 - mean_absolute_error: 0.1514 - val_loss: 0.1427 - val_mean_absolute_error: 0.1890
# Epoch 78/100
# 113/114 [============================>.] - ETA: 0s - loss: 0.0962 - mean_absolute_error: 0.1514Restoring model weights from the end of the best epoch: 68.
# 114/114 [==============================] - 4s 36ms/step - loss: 0.0964 - mean_absolute_error: 0.1515 - val_loss: 0.1484 - val_mean_absolute_error: 0.1923
# Epoch 78: early stopping
# CPU times: user 9min 1s, sys: 37.8 s, total: 9min 39s
# Wall time: 5min 16s

# %%
# plot the losses
plt.figure(figsize = (15,7))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title("Learning curves for the losses")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# history.history['loss']

# %%
# plot the maes
plt.figure(figsize = (15,7))
plt.plot(history.history['mean_absolute_error'], label='Training MAE')
plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
plt.title("Learning curves for the MAE")
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %%
# Now unfreeze the last CNN layer
CNN_model.trainable = True

set_trainable = False

for layer in CNN_model.layers:
    if layer.name == 'conv2d_3':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

# %%
CNN_seq2seq_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 13, None, None, 3)   0         []
#                              ]
#
#  time_distributed (TimeDist  (None, 13, 32)               71808     ['input_1[0][0]']
#  ributed)
#
#  lstm (LSTM)                 [(None, 64),                 24832     ['time_distributed[0][0]']
#                               (None, 64),
#                               (None, 64)]
#
#  repeat_vector (RepeatVecto  (None, 7, 64)                0         ['lstm[0][0]']
#  r)
#
#  lstm_1 (LSTM)               (None, 7, 64)                33024     ['repeat_vector[0][0]',
#                                                                      'lstm[0][1]',
#                                                                      'lstm[0][2]']
#
#  time_distributed_1 (TimeDi  (None, 7, 32)                2080      ['lstm_1[0][0]']
#  stributed)
#
# ==================================================================================================
# Total params: 131744 (514.62 KB)
# Trainable params: 103104 (402.75 KB)
# Non-trainable params: 28640 (111.88 KB)
# __________________________________________________________________________________________________

# %%
# recompile and train the model

# %%
# compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.0009)
CNN_seq2seq_model.compile(loss='mean_squared_error', optimizer=opt, metrics = ['mean_absolute_error'])

# %%
# Early stopping
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', restore_best_weights = True, verbose=1, patience=10)

# %%
# %%time
# Train the model - Maybe we do not need a generator for now, let's see
history_new = CNN_seq2seq_model.fit(X_train, y_train, validation_data = (X_valid, y_valid), epochs = 100, callbacks = [es])
# Out:
# Epoch 1/100
# 2025-07-16 10:36:02.140531: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_2/time_distributed/model_1/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 114/114 [==============================] - 8s 40ms/step - loss: 0.0990 - mean_absolute_error: 0.1569 - val_loss: 0.1361 - val_mean_absolute_error: 0.1869
# Epoch 2/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0983 - mean_absolute_error: 0.1560 - val_loss: 0.1281 - val_mean_absolute_error: 0.1812
# Epoch 3/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0980 - mean_absolute_error: 0.1558 - val_loss: 0.1341 - val_mean_absolute_error: 0.1858
# Epoch 4/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0971 - mean_absolute_error: 0.1534 - val_loss: 0.1342 - val_mean_absolute_error: 0.1837
# Epoch 5/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0969 - mean_absolute_error: 0.1525 - val_loss: 0.1199 - val_mean_absolute_error: 0.1738
# Epoch 6/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0968 - mean_absolute_error: 0.1524 - val_loss: 0.1140 - val_mean_absolute_error: 0.1693
# Epoch 7/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0964 - mean_absolute_error: 0.1516 - val_loss: 0.1304 - val_mean_absolute_error: 0.1812
# Epoch 8/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0973 - mean_absolute_error: 0.1532 - val_loss: 0.1233 - val_mean_absolute_error: 0.1760
# Epoch 9/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0961 - mean_absolute_error: 0.1517 - val_loss: 0.1229 - val_mean_absolute_error: 0.1758
# Epoch 10/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0961 - mean_absolute_error: 0.1522 - val_loss: 0.1177 - val_mean_absolute_error: 0.1728
# Epoch 11/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0948 - mean_absolute_error: 0.1512 - val_loss: 0.1134 - val_mean_absolute_error: 0.1692
# Epoch 12/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0952 - mean_absolute_error: 0.1521 - val_loss: 0.1120 - val_mean_absolute_error: 0.1685
# Epoch 13/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0944 - mean_absolute_error: 0.1512 - val_loss: 0.1111 - val_mean_absolute_error: 0.1706
# Epoch 14/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0938 - mean_absolute_error: 0.1508 - val_loss: 0.1097 - val_mean_absolute_error: 0.1660
# Epoch 15/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0935 - mean_absolute_error: 0.1498 - val_loss: 0.1095 - val_mean_absolute_error: 0.1654
# Epoch 16/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0928 - mean_absolute_error: 0.1490 - val_loss: 0.1120 - val_mean_absolute_error: 0.1675
# Epoch 17/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0928 - mean_absolute_error: 0.1490 - val_loss: 0.1214 - val_mean_absolute_error: 0.1740
# Epoch 18/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0928 - mean_absolute_error: 0.1496 - val_loss: 0.1096 - val_mean_absolute_error: 0.1655
# Epoch 19/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0923 - mean_absolute_error: 0.1487 - val_loss: 0.1093 - val_mean_absolute_error: 0.1670
# Epoch 20/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0919 - mean_absolute_error: 0.1481 - val_loss: 0.1101 - val_mean_absolute_error: 0.1651
# Epoch 21/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0912 - mean_absolute_error: 0.1470 - val_loss: 0.1107 - val_mean_absolute_error: 0.1670
# Epoch 22/100
# 114/114 [==============================] - 4s 36ms/step - loss: 0.0915 - mean_absolute_error: 0.1476 - val_loss: 0.1116 - val_mean_absolute_error: 0.1679
# Epoch 23/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0911 - mean_absolute_error: 0.1472 - val_loss: 0.1122 - val_mean_absolute_error: 0.1671
# Epoch 24/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0916 - mean_absolute_error: 0.1478 - val_loss: 0.1072 - val_mean_absolute_error: 0.1635
# Epoch 25/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0912 - mean_absolute_error: 0.1472 - val_loss: 0.1219 - val_mean_absolute_error: 0.1738
# Epoch 26/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0910 - mean_absolute_error: 0.1469 - val_loss: 0.1053 - val_mean_absolute_error: 0.1618
# Epoch 27/100
# 114/114 [==============================] - 4s 36ms/step - loss: 0.0901 - mean_absolute_error: 0.1461 - val_loss: 0.1039 - val_mean_absolute_error: 0.1608
# Epoch 28/100
# 114/114 [==============================] - 4s 36ms/step - loss: 0.0897 - mean_absolute_error: 0.1458 - val_loss: 0.1089 - val_mean_absolute_error: 0.1636
# Epoch 29/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0910 - mean_absolute_error: 0.1467 - val_loss: 0.1139 - val_mean_absolute_error: 0.1703
# Epoch 30/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0903 - mean_absolute_error: 0.1464 - val_loss: 0.1025 - val_mean_absolute_error: 0.1580
# Epoch 31/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0895 - mean_absolute_error: 0.1447 - val_loss: 0.1069 - val_mean_absolute_error: 0.1633
# Epoch 32/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0899 - mean_absolute_error: 0.1458 - val_loss: 0.1044 - val_mean_absolute_error: 0.1606
# Epoch 33/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0888 - mean_absolute_error: 0.1442 - val_loss: 0.1037 - val_mean_absolute_error: 0.1585
# Epoch 34/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0890 - mean_absolute_error: 0.1444 - val_loss: 0.1067 - val_mean_absolute_error: 0.1616
# Epoch 35/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0888 - mean_absolute_error: 0.1440 - val_loss: 0.1041 - val_mean_absolute_error: 0.1603
# Epoch 36/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0882 - mean_absolute_error: 0.1436 - val_loss: 0.1038 - val_mean_absolute_error: 0.1594
# Epoch 37/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0882 - mean_absolute_error: 0.1430 - val_loss: 0.1057 - val_mean_absolute_error: 0.1611
# Epoch 38/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0878 - mean_absolute_error: 0.1431 - val_loss: 0.1027 - val_mean_absolute_error: 0.1569
# Epoch 39/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0880 - mean_absolute_error: 0.1429 - val_loss: 0.1044 - val_mean_absolute_error: 0.1595
# Epoch 40/100
# 113/114 [============================>.] - ETA: 0s - loss: 0.0873 - mean_absolute_error: 0.1423Restoring model weights from the end of the best epoch: 30.
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0873 - mean_absolute_error: 0.1423 - val_loss: 0.1052 - val_mean_absolute_error: 0.1599
# Epoch 40: early stopping
# CPU times: user 4min 42s, sys: 19.6 s, total: 5min 2s
# Wall time: 2min 44s

# %%
# save this model as keras?

# save this model
model_name_finetuned = 'CNN_seq2seq_non_overlapping_lieanr_activation.keras'
CNN_seq2seq_model.save('models' + '/' + model_name_finetuned)

# %%
# plot the losses
plt.figure(figsize = (15,7))
plt.plot(history_new.history['loss'], label='Training Loss')
plt.plot(history_new.history['val_loss'], label='Validation Loss')
plt.title("Learning curves for the losses")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# history.history['loss']

# %%
# plot the maes
plt.figure(figsize = (15,7))
plt.plot(history_new.history['mean_absolute_error'], label='Training MAE')
plt.plot(history_new.history['val_mean_absolute_error'], label='Validation MAE')
plt.title("Learning curves for the MAE")
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.show()
