# %%
# Let's do the overlapping windows here - We may need to pass the data though a generator to solve the memory issues

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from data_generator import DataGenerator
# Out:
# 2025-07-16 10:47:57.279780: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-16 10:47:57.315776: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-07-16 10:47:57.315800: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-07-16 10:47:57.316713: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-16 10:47:57.322865: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# First import the train and validation data

X_train = np.load("data/Overlapping_data/Train_features_and_targets/all_train_features.npy")
X_valid = np.load("data/Overlapping_data/Valid_features_and_targets/all_valid_features.npy")

# %%
X_train.shape, X_valid.shape
# Out:
# ((49152, 13, 32, 32, 3), (12288, 13, 32, 32, 3))

# %%
y_train = np.load("data/Overlapping_data/Train_features_and_targets/all_train_targets.npy")
y_valid = np.load("data/Overlapping_data/Valid_features_and_targets/all_valid_targets.npy")

# %%
y_train.shape, y_valid.shape
# Out:
# ((49152, 7, 32), (12288, 7, 32))

# %%
# Let's redefine the model here

# %%
# We need our CNN model
CNN_model = tf.keras.models.load_model('../../Spring_2024/Bayes_for_comps/TS_bayes_implementation_for_TN/models/trained_gmp_model_dense_32_new.h5')
# Out:
# 2025-07-16 10:48:32.856100: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31134 MB memory:  -> device: 0, name: Tesla V100S-PCIE-32GB, pci bus id: 0000:06:00.0, compute capability: 7.0

# %%
# Define the reduced model

# last layer
output_reduced = CNN_model.layers[-11].output

reduced_model = tf.keras.models.Model(inputs = CNN_model.input, outputs = output_reduced)

reduced_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  conv2d (Conv2D)             (None, None, None, 32)    896
#
#  activation (Activation)     (None, None, None, 32)    0
#
#  conv2d_1 (Conv2D)           (None, None, None, 32)    9248
#
#  activation_1 (Activation)   (None, None, None, 32)    0
#
#  max_pooling2d (MaxPooling2  (None, None, None, 32)    0
#  D)
#
#  dropout (Dropout)           (None, None, None, 32)    0
#
#  conv2d_2 (Conv2D)           (None, None, None, 64)    18496
#
#  activation_2 (Activation)   (None, None, None, 64)    0
#
#  conv2d_3 (Conv2D)           (None, None, None, 64)    36928
#
#  activation_3 (Activation)   (None, None, None, 64)    0
#
#  max_pooling2d_1 (MaxPoolin  (None, None, None, 64)    0
#  g2D)
#
# =================================================================
# Total params: 65568 (256.12 KB)
# Trainable params: 36928 (144.25 KB)
# Non-trainable params: 28640 (111.88 KB)
# _________________________________________________________________

# %%
# okay, now need to add back the dropout, the dense and activation

# add dropout
added_dropout = tf.keras.layers.Dropout(0.5, name = "New_dropout_0")(CNN_model.layers[-11].output)

# add global max pooling
added_flatten = tf.keras.layers.GlobalMaxPooling2D()(added_dropout)

# add dense
added_dense = tf.keras.layers.Dense(64, name = "New_Dense_0")(added_flatten)

# add activation
added_Act = tf.keras.layers.Activation('relu', name = "New_Activation_0")(added_dense)

# add dropout
added_dropout2 = tf.keras.layers.Dropout(0.5, name = "New_dropout_1")(added_Act)

# # add another dense
added_dense_1 = tf.keras.layers.Dense(32, name = "New_Dense_1")(added_dropout2)

# # add activation
added_Act_1 = tf.keras.layers.Activation('relu', name = "New_Activation_1")(added_dense_1)

new_model = tf.keras.models.Model(CNN_model.input, added_Act_1)

# %%
new_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  conv2d (Conv2D)             (None, None, None, 32)    896
#
#  activation (Activation)     (None, None, None, 32)    0
#
#  conv2d_1 (Conv2D)           (None, None, None, 32)    9248
#
#  activation_1 (Activation)   (None, None, None, 32)    0
#
#  max_pooling2d (MaxPooling2  (None, None, None, 32)    0
#  D)
#
#  dropout (Dropout)           (None, None, None, 32)    0
#
#  conv2d_2 (Conv2D)           (None, None, None, 64)    18496
#
#  activation_2 (Activation)   (None, None, None, 64)    0
#
#  conv2d_3 (Conv2D)           (None, None, None, 64)    36928
#
#  activation_3 (Activation)   (None, None, None, 64)    0
#
#  max_pooling2d_1 (MaxPoolin  (None, None, None, 64)    0
#  g2D)
#
#  New_dropout_0 (Dropout)     (None, None, None, 64)    0
#
#  global_max_pooling2d (Glob  (None, 64)                0
#  alMaxPooling2D)
#
#  New_Dense_0 (Dense)         (None, 64)                4160
#
#  New_Activation_0 (Activati  (None, 64)                0
#  on)
#
#  New_dropout_1 (Dropout)     (None, 64)                0
#
#  New_Dense_1 (Dense)         (None, 32)                2080
#
#  New_Activation_1 (Activati  (None, 32)                0
#  on)
#
# =================================================================
# Total params: 71808 (280.50 KB)
# Trainable params: 43168 (168.62 KB)
# Non-trainable params: 28640 (111.88 KB)
# _________________________________________________________________

# %%
# Pass this thorugh the TD layer, and add the rest of the encoder decoder model for our exercise
input_time = 13
feature_size = 32
output_time = 7

# Encoder
# define encoder input
encoder_input = tf.keras.layers.Input(shape = (input_time, None, None, 3)) 

# pass the feature extractor model through a TD layer
td_model = tf.keras.layers.TimeDistributed(new_model)

td_out = td_model(encoder_input)

# add an lstm to process the input sequence
lstm_layer = tf.keras.layers.LSTM(64, activation = "relu", return_state = True, return_sequences = False)

encoder_outputs, state_h, state_c = lstm_layer(td_out)

# Decoder

# repeat the context vector 7 times
decoder_inp = tf.keras.layers.RepeatVector(output_time)(encoder_outputs)

# define an LSTM for the output sequence
decoder_lstm = tf.keras.layers.LSTM(64, return_sequences = True, activation = 'relu')

decoder_out = decoder_lstm(decoder_inp, initial_state = [state_h, state_c])

# TD dense layer to generate the output sequnces
dense_layer = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(feature_size))

dense_out = dense_layer(decoder_out)

# define the model
CNN_seq2seq_model = tf.keras.models.Model(inputs = encoder_input, outputs = dense_out)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
CNN_seq2seq_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 13, None, None, 3)   0         []
#                              ]
#
#  time_distributed (TimeDist  (None, 13, 32)               71808     ['input_1[0][0]']
#  ributed)
#
#  lstm (LSTM)                 [(None, 64),                 24832     ['time_distributed[0][0]']
#                               (None, 64),
#                               (None, 64)]
#
#  repeat_vector (RepeatVecto  (None, 7, 64)                0         ['lstm[0][0]']
#  r)
#
#  lstm_1 (LSTM)               (None, 7, 64)                33024     ['repeat_vector[0][0]',
#                                                                      'lstm[0][1]',
#                                                                      'lstm[0][2]']
#
#  time_distributed_1 (TimeDi  (None, 7, 32)                2080      ['lstm_1[0][0]']
#  stributed)
#
# ==================================================================================================
# Total params: 131744 (514.62 KB)
# Trainable params: 103104 (402.75 KB)
# Non-trainable params: 28640 (111.88 KB)
# __________________________________________________________________________________________________

# %%
# now, we can freeze the laeyr weights of the CNN model (the CNN layers at least)

# freeze the layers
for layer in CNN_model.layers:
    layer.trainable = False

# %%
# Final model before unfreezing - verify the required weights are frozen?
CNN_seq2seq_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 13, None, None, 3)   0         []
#                              ]
#
#  time_distributed (TimeDist  (None, 13, 32)               71808     ['input_1[0][0]']
#  ributed)
#
#  lstm (LSTM)                 [(None, 64),                 24832     ['time_distributed[0][0]']
#                               (None, 64),
#                               (None, 64)]
#
#  repeat_vector (RepeatVecto  (None, 7, 64)                0         ['lstm[0][0]']
#  r)
#
#  lstm_1 (LSTM)               (None, 7, 64)                33024     ['repeat_vector[0][0]',
#                                                                      'lstm[0][1]',
#                                                                      'lstm[0][2]']
#
#  time_distributed_1 (TimeDi  (None, 7, 32)                2080      ['lstm_1[0][0]']
#  stributed)
#
# ==================================================================================================
# Total params: 131744 (514.62 KB)
# Trainable params: 66176 (258.50 KB)
# Non-trainable params: 65568 (256.12 KB)
# __________________________________________________________________________________________________

# %%
# Use a data generator? for model training validation and inference?

# %%
# %%time
batch_size = 32
generator_batch_size = 32
train_gen = DataGenerator(X_train, y_train, batch_size, shuffle=False)
val_gen = DataGenerator(X_valid, y_valid, batch_size, shuffle=False)
# Out:
# CPU times: user 63 µs, sys: 311 µs, total: 374 µs
# Wall time: 235 µs

# %%
steps_per_epoch = int(np.ceil(len(X_train) / batch_size))
train_steps = int(np.ceil(len(X_train) / generator_batch_size))
validation_steps = int(np.ceil(len(X_valid) / generator_batch_size))

# %%
# %%time

# Since the training is taking too much time and we would like to figure out the inference part, let's have the patience at 2 and run it just for 10 epochs
# compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
CNN_seq2seq_model.compile(loss='mean_squared_error', optimizer=opt, metrics = ['mean_absolute_error'])
    
# add early stopping
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', restore_best_weights = True, verbose=1, patience=10)

# fit the generator - the steps are a must here
history = CNN_seq2seq_model.fit(train_gen,
          validation_data = val_gen, steps_per_epoch=steps_per_epoch, 
                                  validation_steps=validation_steps,           
          epochs = 100, callbacks = [es])
# Out:
# Epoch 1/100
# 2025-07-16 10:48:35.886137: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_2/time_distributed/model_1/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2025-07-16 10:48:36.291733: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2025-07-16 10:48:37.830690: I external/local_xla/xla/service/service.cc:168] XLA service 0x14caeced9b30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-07-16 10:48:37.830726: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100S-PCIE-32GB, Compute Capability 7.0
# 2025-07-16 10:48:37.838384: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752680917.946214  714188 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1536/1536 [==============================] - 59s 36ms/step - loss: 0.1411 - mean_absolute_error: 0.1971 - val_loss: 0.2247 - val_mean_absolute_error: 0.2348
# Epoch 2/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.1035 - mean_absolute_error: 0.1633 - val_loss: 0.1912 - val_mean_absolute_error: 0.2161
# Epoch 3/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.1015 - mean_absolute_error: 0.1592 - val_loss: 0.1729 - val_mean_absolute_error: 0.2061
# Epoch 4/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.1006 - mean_absolute_error: 0.1572 - val_loss: 0.1650 - val_mean_absolute_error: 0.2006
# Epoch 5/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0998 - mean_absolute_error: 0.1555 - val_loss: 0.1576 - val_mean_absolute_error: 0.1980
# Epoch 6/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0992 - mean_absolute_error: 0.1544 - val_loss: 0.1402 - val_mean_absolute_error: 0.1868
# Epoch 7/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0987 - mean_absolute_error: 0.1535 - val_loss: 0.1403 - val_mean_absolute_error: 0.1864
# Epoch 8/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0985 - mean_absolute_error: 0.1529 - val_loss: 0.1406 - val_mean_absolute_error: 0.1860
# Epoch 9/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0983 - mean_absolute_error: 0.1523 - val_loss: 0.1429 - val_mean_absolute_error: 0.1879
# Epoch 10/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0981 - mean_absolute_error: 0.1519 - val_loss: 0.1438 - val_mean_absolute_error: 0.1875
# Epoch 11/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0978 - mean_absolute_error: 0.1514 - val_loss: 0.1340 - val_mean_absolute_error: 0.1810
# Epoch 12/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0976 - mean_absolute_error: 0.1513 - val_loss: 0.1389 - val_mean_absolute_error: 0.1846
# Epoch 13/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0974 - mean_absolute_error: 0.1509 - val_loss: 0.1377 - val_mean_absolute_error: 0.1835
# Epoch 14/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0972 - mean_absolute_error: 0.1507 - val_loss: 0.1314 - val_mean_absolute_error: 0.1799
# Epoch 15/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0969 - mean_absolute_error: 0.1504 - val_loss: 0.1371 - val_mean_absolute_error: 0.1836
# Epoch 16/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0966 - mean_absolute_error: 0.1503 - val_loss: 0.1282 - val_mean_absolute_error: 0.1786
# Epoch 17/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0963 - mean_absolute_error: 0.1502 - val_loss: 0.1270 - val_mean_absolute_error: 0.1771
# Epoch 18/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0960 - mean_absolute_error: 0.1501 - val_loss: 0.1359 - val_mean_absolute_error: 0.1835
# Epoch 19/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0957 - mean_absolute_error: 0.1499 - val_loss: 0.1297 - val_mean_absolute_error: 0.1796
# Epoch 20/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0951 - mean_absolute_error: 0.1497 - val_loss: 0.1385 - val_mean_absolute_error: 0.1851
# Epoch 21/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0949 - mean_absolute_error: 0.1495 - val_loss: 0.1305 - val_mean_absolute_error: 0.1791
# Epoch 22/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0947 - mean_absolute_error: 0.1492 - val_loss: 0.1238 - val_mean_absolute_error: 0.1743
# Epoch 23/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0944 - mean_absolute_error: 0.1486 - val_loss: 0.1246 - val_mean_absolute_error: 0.1754
# Epoch 24/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0941 - mean_absolute_error: 0.1483 - val_loss: 0.1251 - val_mean_absolute_error: 0.1756
# Epoch 25/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0939 - mean_absolute_error: 0.1479 - val_loss: 0.1205 - val_mean_absolute_error: 0.1711
# Epoch 26/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0937 - mean_absolute_error: 0.1476 - val_loss: 0.1202 - val_mean_absolute_error: 0.1712
# Epoch 27/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0936 - mean_absolute_error: 0.1473 - val_loss: 0.1184 - val_mean_absolute_error: 0.1693
# Epoch 28/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0934 - mean_absolute_error: 0.1470 - val_loss: 0.1218 - val_mean_absolute_error: 0.1723
# Epoch 29/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0932 - mean_absolute_error: 0.1468 - val_loss: 0.1174 - val_mean_absolute_error: 0.1690
# Epoch 30/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0931 - mean_absolute_error: 0.1466 - val_loss: 0.1239 - val_mean_absolute_error: 0.1739
# Epoch 31/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0929 - mean_absolute_error: 0.1464 - val_loss: 0.1216 - val_mean_absolute_error: 0.1715
# Epoch 32/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0927 - mean_absolute_error: 0.1462 - val_loss: 0.1207 - val_mean_absolute_error: 0.1708
# Epoch 33/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0926 - mean_absolute_error: 0.1460 - val_loss: 0.1225 - val_mean_absolute_error: 0.1725
# Epoch 34/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0925 - mean_absolute_error: 0.1458 - val_loss: 0.1218 - val_mean_absolute_error: 0.1718
# Epoch 35/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0925 - mean_absolute_error: 0.1457 - val_loss: 0.1163 - val_mean_absolute_error: 0.1680
# Epoch 36/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0923 - mean_absolute_error: 0.1455 - val_loss: 0.1201 - val_mean_absolute_error: 0.1699
# Epoch 37/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0920 - mean_absolute_error: 0.1451 - val_loss: 0.1199 - val_mean_absolute_error: 0.1706
# Epoch 38/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0920 - mean_absolute_error: 0.1450 - val_loss: 0.1216 - val_mean_absolute_error: 0.1717
# Epoch 39/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0919 - mean_absolute_error: 0.1449 - val_loss: 0.1234 - val_mean_absolute_error: 0.1727
# Epoch 40/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0917 - mean_absolute_error: 0.1447 - val_loss: 0.1177 - val_mean_absolute_error: 0.1684
# Epoch 41/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0916 - mean_absolute_error: 0.1445 - val_loss: 0.1226 - val_mean_absolute_error: 0.1724
# Epoch 42/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0915 - mean_absolute_error: 0.1443 - val_loss: 0.1122 - val_mean_absolute_error: 0.1639
# Epoch 43/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0914 - mean_absolute_error: 0.1442 - val_loss: 0.1219 - val_mean_absolute_error: 0.1711
# Epoch 44/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0912 - mean_absolute_error: 0.1440 - val_loss: 0.1165 - val_mean_absolute_error: 0.1673
# Epoch 45/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0912 - mean_absolute_error: 0.1440 - val_loss: 0.1125 - val_mean_absolute_error: 0.1642
# Epoch 46/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0912 - mean_absolute_error: 0.1439 - val_loss: 0.1208 - val_mean_absolute_error: 0.1703
# Epoch 47/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0911 - mean_absolute_error: 0.1437 - val_loss: 0.1194 - val_mean_absolute_error: 0.1695
# Epoch 48/100
# 1536/1536 [==============================] - 53s 35ms/step - loss: 0.0909 - mean_absolute_error: 0.1435 - val_loss: 0.1133 - val_mean_absolute_error: 0.1652
# Epoch 49/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0909 - mean_absolute_error: 0.1434 - val_loss: 0.1151 - val_mean_absolute_error: 0.1657
# Epoch 50/100
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0908 - mean_absolute_error: 0.1433 - val_loss: 0.1128 - val_mean_absolute_error: 0.1641
# Epoch 51/100
# 1536/1536 [==============================] - 53s 35ms/step - loss: 0.0906 - mean_absolute_error: 0.1430 - val_loss: 0.1171 - val_mean_absolute_error: 0.1674
# Epoch 52/100
# 1535/1536 [============================>.] - ETA: 0s - loss: 0.0907 - mean_absolute_error: 0.1431Restoring model weights from the end of the best epoch: 42.
# 1536/1536 [==============================] - 54s 35ms/step - loss: 0.0907 - mean_absolute_error: 0.1431 - val_loss: 0.1227 - val_mean_absolute_error: 0.1711
# Epoch 52: early stopping
# CPU times: user 1h 27min 49s, sys: 5min 39s, total: 1h 33min 28s
# Wall time: 46min 54s

# %%
# plot the losses
plt.figure(figsize = (15,7))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title("Learning curves for the losses")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# history.history['loss']

# %%
# plot the maes
plt.figure(figsize = (15,7))
plt.plot(history.history['mean_absolute_error'], label='Training MAE')
plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
plt.title("Learning curves for the MAE")
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %%
# Now unfreeze the last CNN layer
CNN_model.trainable = True

set_trainable = False

for layer in CNN_model.layers:
    if layer.name == 'conv2d_3':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

# %%
CNN_seq2seq_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 13, None, None, 3)   0         []
#                              ]
#
#  time_distributed (TimeDist  (None, 13, 32)               71808     ['input_1[0][0]']
#  ributed)
#
#  lstm (LSTM)                 [(None, 64),                 24832     ['time_distributed[0][0]']
#                               (None, 64),
#                               (None, 64)]
#
#  repeat_vector (RepeatVecto  (None, 7, 64)                0         ['lstm[0][0]']
#  r)
#
#  lstm_1 (LSTM)               (None, 7, 64)                33024     ['repeat_vector[0][0]',
#                                                                      'lstm[0][1]',
#                                                                      'lstm[0][2]']
#
#  time_distributed_1 (TimeDi  (None, 7, 32)                2080      ['lstm_1[0][0]']
#  stributed)
#
# ==================================================================================================
# Total params: 131744 (514.62 KB)
# Trainable params: 103104 (402.75 KB)
# Non-trainable params: 28640 (111.88 KB)
# __________________________________________________________________________________________________

# %%
# %%time

# Same here, we are just running it for 2 epochs for the sake of completion with a patience of 1 - we will properly trin the model overnight. 
# compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.0009)
CNN_seq2seq_model.compile(loss='mean_squared_error', optimizer=opt, metrics = ['mean_absolute_error'])
    
# add early stopping
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', restore_best_weights = True, verbose=1, patience=10)

# fit the generator - the steps are a must here
history_new = CNN_seq2seq_model.fit(train_gen,
          validation_data = val_gen, steps_per_epoch=steps_per_epoch, 
                                  validation_steps=validation_steps,           
          epochs = 100, callbacks = [es])
# Out:
# Epoch 1/100
# 2025-07-16 11:35:30.633404: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_2/time_distributed/model_1/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 1536/1536 [==============================] - 60s 37ms/step - loss: 0.0957 - mean_absolute_error: 0.1495 - val_loss: 0.1155 - val_mean_absolute_error: 0.1665
# Epoch 2/100
# 1536/1536 [==============================] - 57s 37ms/step - loss: 0.0942 - mean_absolute_error: 0.1470 - val_loss: 0.1078 - val_mean_absolute_error: 0.1576
# Epoch 3/100
# 1536/1536 [==============================] - 57s 37ms/step - loss: 0.0927 - mean_absolute_error: 0.1451 - val_loss: 0.1079 - val_mean_absolute_error: 0.1589
# Epoch 4/100
# 1536/1536 [==============================] - 56s 37ms/step - loss: 0.0919 - mean_absolute_error: 0.1440 - val_loss: 0.1070 - val_mean_absolute_error: 0.1573
# Epoch 5/100
# 1536/1536 [==============================] - 57s 37ms/step - loss: 0.0907 - mean_absolute_error: 0.1425 - val_loss: 0.1043 - val_mean_absolute_error: 0.1538
# Epoch 6/100
# 1536/1536 [==============================] - 56s 37ms/step - loss: 0.0900 - mean_absolute_error: 0.1416 - val_loss: 0.1050 - val_mean_absolute_error: 0.1552
# Epoch 7/100
# 1536/1536 [==============================] - 57s 37ms/step - loss: 0.0894 - mean_absolute_error: 0.1407 - val_loss: 0.1047 - val_mean_absolute_error: 0.1554
# Epoch 8/100
# 1536/1536 [==============================] - 57s 37ms/step - loss: 0.0886 - mean_absolute_error: 0.1400 - val_loss: 0.1034 - val_mean_absolute_error: 0.1541
# Epoch 9/100
# 1536/1536 [==============================] - 57s 37ms/step - loss: 0.0882 - mean_absolute_error: 0.1395 - val_loss: 0.1038 - val_mean_absolute_error: 0.1542
# Epoch 10/100
# 1536/1536 [==============================] - 57s 37ms/step - loss: 0.0873 - mean_absolute_error: 0.1386 - val_loss: 0.1054 - val_mean_absolute_error: 0.1547
# Epoch 11/100
# 1536/1536 [==============================] - 56s 37ms/step - loss: 0.0870 - mean_absolute_error: 0.1383 - val_loss: 0.1041 - val_mean_absolute_error: 0.1532
# Epoch 12/100
# 1536/1536 [==============================] - 57s 37ms/step - loss: 0.0862 - mean_absolute_error: 0.1376 - val_loss: 0.1044 - val_mean_absolute_error: 0.1541
# Epoch 13/100
# 1536/1536 [==============================] - 57s 37ms/step - loss: 0.0860 - mean_absolute_error: 0.1373 - val_loss: 0.1069 - val_mean_absolute_error: 0.1560
# Epoch 14/100
# 1536/1536 [==============================] - 57s 37ms/step - loss: 0.0853 - mean_absolute_error: 0.1366 - val_loss: 0.1038 - val_mean_absolute_error: 0.1526
# Epoch 15/100
# 1536/1536 [==============================] - 57s 37ms/step - loss: 0.0849 - mean_absolute_error: 0.1363 - val_loss: 0.1029 - val_mean_absolute_error: 0.1509
# Epoch 16/100
# 1536/1536 [==============================] - 57s 37ms/step - loss: 0.0847 - mean_absolute_error: 0.1360 - val_loss: 0.1039 - val_mean_absolute_error: 0.1514
# Epoch 17/100
# 1536/1536 [==============================] - 56s 37ms/step - loss: 0.0838 - mean_absolute_error: 0.1352 - val_loss: 0.1031 - val_mean_absolute_error: 0.1526
# Epoch 18/100
# 1536/1536 [==============================] - 57s 37ms/step - loss: 0.0838 - mean_absolute_error: 0.1352 - val_loss: 0.1049 - val_mean_absolute_error: 0.1557
# Epoch 19/100
# 1536/1536 [==============================] - 56s 37ms/step - loss: 0.0832 - mean_absolute_error: 0.1346 - val_loss: 0.1042 - val_mean_absolute_error: 0.1530
# Epoch 20/100
# 1536/1536 [==============================] - 56s 37ms/step - loss: 0.0829 - mean_absolute_error: 0.1344 - val_loss: 0.1036 - val_mean_absolute_error: 0.1536
# Epoch 21/100
# 1536/1536 [==============================] - 57s 37ms/step - loss: 0.0826 - mean_absolute_error: 0.1340 - val_loss: 0.1052 - val_mean_absolute_error: 0.1535
# Epoch 22/100
# 1536/1536 [==============================] - 56s 37ms/step - loss: 0.0823 - mean_absolute_error: 0.1338 - val_loss: 0.1056 - val_mean_absolute_error: 0.1540
# Epoch 23/100
# 1536/1536 [==============================] - 56s 37ms/step - loss: 0.0819 - mean_absolute_error: 0.1334 - val_loss: 0.1045 - val_mean_absolute_error: 0.1531
# Epoch 24/100
# 1536/1536 [==============================] - 57s 37ms/step - loss: 0.0813 - mean_absolute_error: 0.1329 - val_loss: 0.1037 - val_mean_absolute_error: 0.1529
# Epoch 25/100
# 1535/1536 [============================>.] - ETA: 0s - loss: 0.0811 - mean_absolute_error: 0.1327Restoring model weights from the end of the best epoch: 15.
# 1536/1536 [==============================] - 56s 37ms/step - loss: 0.0811 - mean_absolute_error: 0.1327 - val_loss: 0.1063 - val_mean_absolute_error: 0.1539
# Epoch 25: early stopping
# CPU times: user 44min 5s, sys: 2min 47s, total: 46min 53s
# Wall time: 23min 38s

# %%
# save this model as keras? resave this after running it properly

# save this model
model_name_finetuned = 'CNN_seq2seq_overlapping_linear_activation.keras'
CNN_seq2seq_model.save('models' + '/' + model_name_finetuned)

# %%
# plot the losses
plt.figure(figsize = (15,7))
plt.plot(history_new.history['loss'], label='Training Loss')
plt.plot(history_new.history['val_loss'], label='Validation Loss')
plt.title("Learning curves for the losses")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# history.history['loss']

# %%
# plot the maes
plt.figure(figsize = (15,7))
plt.plot(history_new.history['mean_absolute_error'], label='Training MAE')
plt.plot(history_new.history['val_mean_absolute_error'], label='Validation MAE')
plt.title("Learning curves for the MAE")
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.show()
