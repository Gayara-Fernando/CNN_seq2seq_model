# %%
# We have preprocessed the data, and previously written out the architecture. Let's import the data here and rewrite the model here. The model will now have to be trained first with frozen layer weights and then with unfrozen layer weights.

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# 2025-07-15 10:47:08.027241: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-15 10:47:08.063248: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-07-15 10:47:08.063273: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-07-15 10:47:08.064194: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-15 10:47:08.070072: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# First import the train and validation data

X_train = np.load("data/train_input_sub_images/all_train_data.npy")
X_valid = np.load("data/valid_input_sub_images/all_valid_data.npy")

# %%
X_train.shape, X_valid.shape
# Out:
# ((3640, 13, 30, 30, 3), (910, 13, 30, 30, 3))

# %%
y_train = np.load("data/train_out_targets/all_train_targets.npy")
y_valid = np.load("data/valid_out_targets/all_valid_targets.npy")

# %%
y_train.shape, y_valid.shape
# Out:
# ((3640, 7, 32), (910, 7, 32))

# %%
# Let's redefine the model here

# %%
# We need our CNN model
CNN_model = tf.keras.models.load_model('../../Spring_2024/Bayes_for_comps/TS_bayes_implementation_for_TN/models/trained_gmp_model_dense_32_new.h5')
# Out:
# 2025-07-15 10:47:10.716228: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31134 MB memory:  -> device: 0, name: Tesla V100S-PCIE-32GB, pci bus id: 0000:86:00.0, compute capability: 7.0

# %%
# Define the reduced model

# last layer
output_reduced = CNN_model.layers[-11].output

reduced_model = tf.keras.models.Model(inputs = CNN_model.input, outputs = output_reduced)

reduced_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  conv2d (Conv2D)             (None, None, None, 32)    896
#
#  activation (Activation)     (None, None, None, 32)    0
#
#  conv2d_1 (Conv2D)           (None, None, None, 32)    9248
#
#  activation_1 (Activation)   (None, None, None, 32)    0
#
#  max_pooling2d (MaxPooling2  (None, None, None, 32)    0
#  D)
#
#  dropout (Dropout)           (None, None, None, 32)    0
#
#  conv2d_2 (Conv2D)           (None, None, None, 64)    18496
#
#  activation_2 (Activation)   (None, None, None, 64)    0
#
#  conv2d_3 (Conv2D)           (None, None, None, 64)    36928
#
#  activation_3 (Activation)   (None, None, None, 64)    0
#
#  max_pooling2d_1 (MaxPoolin  (None, None, None, 64)    0
#  g2D)
#
# =================================================================
# Total params: 65568 (256.12 KB)
# Trainable params: 36928 (144.25 KB)
# Non-trainable params: 28640 (111.88 KB)
# _________________________________________________________________

# %%
# okay, now need to add back the dropout, the dense and activation

# add dropout
added_dropout = tf.keras.layers.Dropout(0.5, name = "New_dropout_0")(CNN_model.layers[-11].output)

# add global max pooling
added_flatten = tf.keras.layers.GlobalMaxPooling2D()(added_dropout)

# add dense
added_dense = tf.keras.layers.Dense(64, name = "New_Dense_0")(added_flatten)

# add activation
added_Act = tf.keras.layers.Activation('relu', name = "New_Activation_0")(added_dense)

# add dropout
added_dropout2 = tf.keras.layers.Dropout(0.5, name = "New_dropout_1")(added_Act)

# # add another dense
added_dense_1 = tf.keras.layers.Dense(32, name = "New_Dense_1")(added_dropout2)

# # add activation
added_Act_1 = tf.keras.layers.Activation('relu', name = "New_Activation_1")(added_dense_1)

new_model = tf.keras.models.Model(CNN_model.input, added_Act_1)

# %%
new_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  conv2d (Conv2D)             (None, None, None, 32)    896
#
#  activation (Activation)     (None, None, None, 32)    0
#
#  conv2d_1 (Conv2D)           (None, None, None, 32)    9248
#
#  activation_1 (Activation)   (None, None, None, 32)    0
#
#  max_pooling2d (MaxPooling2  (None, None, None, 32)    0
#  D)
#
#  dropout (Dropout)           (None, None, None, 32)    0
#
#  conv2d_2 (Conv2D)           (None, None, None, 64)    18496
#
#  activation_2 (Activation)   (None, None, None, 64)    0
#
#  conv2d_3 (Conv2D)           (None, None, None, 64)    36928
#
#  activation_3 (Activation)   (None, None, None, 64)    0
#
#  max_pooling2d_1 (MaxPoolin  (None, None, None, 64)    0
#  g2D)
#
#  New_dropout_0 (Dropout)     (None, None, None, 64)    0
#
#  global_max_pooling2d (Glob  (None, 64)                0
#  alMaxPooling2D)
#
#  New_Dense_0 (Dense)         (None, 64)                4160
#
#  New_Activation_0 (Activati  (None, 64)                0
#  on)
#
#  New_dropout_1 (Dropout)     (None, 64)                0
#
#  New_Dense_1 (Dense)         (None, 32)                2080
#
#  New_Activation_1 (Activati  (None, 32)                0
#  on)
#
# =================================================================
# Total params: 71808 (280.50 KB)
# Trainable params: 43168 (168.62 KB)
# Non-trainable params: 28640 (111.88 KB)
# _________________________________________________________________

# %%
# Pass this thorugh the TD layer, and add the rest of the encoder decoder model for our exercise
input_time = 13
feature_size = 32
output_time = 7

# Encoder
# define encoder input
encoder_input = tf.keras.layers.Input(shape = (input_time, None, None, 3)) 

# pass the feature extractor model through a TD layer
td_model = tf.keras.layers.TimeDistributed(new_model)

td_out = td_model(encoder_input)

# add an lstm to process the input sequence
lstm_layer = tf.keras.layers.LSTM(64, activation = "relu", return_state = True, return_sequences = False)

encoder_outputs, state_h, state_c = lstm_layer(td_out)

# Decoder

# repeat the context vector 7 times
decoder_inp = tf.keras.layers.RepeatVector(output_time)(encoder_outputs)

# define an LSTM for the output sequence
decoder_lstm = tf.keras.layers.LSTM(64, return_sequences = True, activation = 'relu')

decoder_out = decoder_lstm(decoder_inp, initial_state = [state_h, state_c])

# TD dense layer to generate the output sequnces
dense_layer = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(feature_size, activation = 'relu'))

dense_out = dense_layer(decoder_out)

# define the model
CNN_seq2seq_model = tf.keras.models.Model(inputs = encoder_input, outputs = dense_out)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
CNN_seq2seq_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 13, None, None, 3)   0         []
#                              ]
#
#  time_distributed (TimeDist  (None, 13, 32)               71808     ['input_1[0][0]']
#  ributed)
#
#  lstm (LSTM)                 [(None, 64),                 24832     ['time_distributed[0][0]']
#                               (None, 64),
#                               (None, 64)]
#
#  repeat_vector (RepeatVecto  (None, 7, 64)                0         ['lstm[0][0]']
#  r)
#
#  lstm_1 (LSTM)               (None, 7, 64)                33024     ['repeat_vector[0][0]',
#                                                                      'lstm[0][1]',
#                                                                      'lstm[0][2]']
#
#  time_distributed_1 (TimeDi  (None, 7, 32)                2080      ['lstm_1[0][0]']
#  stributed)
#
# ==================================================================================================
# Total params: 131744 (514.62 KB)
# Trainable params: 103104 (402.75 KB)
# Non-trainable params: 28640 (111.88 KB)
# __________________________________________________________________________________________________

# %%
# now, we can freeze the laeyr weights of the CNN model (the CNN layers at least)

# freeze the layers
for layer in CNN_model.layers:
    layer.trainable = False

# %%
# Final model before unfreezing - verify the required weights are frozen?
CNN_seq2seq_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 13, None, None, 3)   0         []
#                              ]
#
#  time_distributed (TimeDist  (None, 13, 32)               71808     ['input_1[0][0]']
#  ributed)
#
#  lstm (LSTM)                 [(None, 64),                 24832     ['time_distributed[0][0]']
#                               (None, 64),
#                               (None, 64)]
#
#  repeat_vector (RepeatVecto  (None, 7, 64)                0         ['lstm[0][0]']
#  r)
#
#  lstm_1 (LSTM)               (None, 7, 64)                33024     ['repeat_vector[0][0]',
#                                                                      'lstm[0][1]',
#                                                                      'lstm[0][2]']
#
#  time_distributed_1 (TimeDi  (None, 7, 32)                2080      ['lstm_1[0][0]']
#  stributed)
#
# ==================================================================================================
# Total params: 131744 (514.62 KB)
# Trainable params: 66176 (258.50 KB)
# Non-trainable params: 65568 (256.12 KB)
# __________________________________________________________________________________________________

# %%
# Okay, now let's train the frozen model

# compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
CNN_seq2seq_model.compile(loss='mean_squared_error', optimizer=opt, metrics = ['mean_absolute_error'])

# %%
# add early stopping
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', restore_best_weights = True, verbose=1, patience=10)

# %%
# %%time
# Train the model - Maybe we do not need a generator for now, let's see
history = CNN_seq2seq_model.fit(X_train, y_train, validation_data = (X_valid, y_valid), epochs = 100, callbacks = [es])
# Out:
# Epoch 1/100
# 2025-07-15 10:47:14.073064: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_2/time_distributed/model_1/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2025-07-15 10:47:14.459822: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2025-07-15 10:47:15.927197: I external/local_xla/xla/service/service.cc:168] XLA service 0x14e724ddd3c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-07-15 10:47:15.927232: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100S-PCIE-32GB, Compute Capability 7.0
# 2025-07-15 10:47:15.935040: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752594436.046755  207749 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 114/114 [==============================] - 9s 42ms/step - loss: 0.3902 - mean_absolute_error: 0.3320 - val_loss: 0.3827 - val_mean_absolute_error: 0.3102
# Epoch 2/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.2317 - mean_absolute_error: 0.2288 - val_loss: 0.3505 - val_mean_absolute_error: 0.2890
# Epoch 3/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.2164 - mean_absolute_error: 0.2135 - val_loss: 0.3185 - val_mean_absolute_error: 0.2725
# Epoch 4/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.1864 - mean_absolute_error: 0.1959 - val_loss: 0.2956 - val_mean_absolute_error: 0.2610
# Epoch 5/100
# 114/114 [==============================] - 4s 36ms/step - loss: 0.1847 - mean_absolute_error: 0.1940 - val_loss: 0.2922 - val_mean_absolute_error: 0.2590
# Epoch 6/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1835 - mean_absolute_error: 0.1929 - val_loss: 0.2748 - val_mean_absolute_error: 0.2501
# Epoch 7/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.1829 - mean_absolute_error: 0.1922 - val_loss: 0.2727 - val_mean_absolute_error: 0.2489
# Epoch 8/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.1825 - mean_absolute_error: 0.1919 - val_loss: 0.2739 - val_mean_absolute_error: 0.2492
# Epoch 9/100
# 114/114 [==============================] - 4s 36ms/step - loss: 0.1820 - mean_absolute_error: 0.1914 - val_loss: 0.2712 - val_mean_absolute_error: 0.2476
# Epoch 10/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.1814 - mean_absolute_error: 0.1909 - val_loss: 0.2669 - val_mean_absolute_error: 0.2452
# Epoch 11/100
# 114/114 [==============================] - 4s 36ms/step - loss: 0.1813 - mean_absolute_error: 0.1907 - val_loss: 0.2657 - val_mean_absolute_error: 0.2445
# Epoch 12/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.1816 - mean_absolute_error: 0.1910 - val_loss: 0.2555 - val_mean_absolute_error: 0.2389
# Epoch 13/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.1808 - mean_absolute_error: 0.1903 - val_loss: 0.2563 - val_mean_absolute_error: 0.2393
# Epoch 14/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1806 - mean_absolute_error: 0.1901 - val_loss: 0.2487 - val_mean_absolute_error: 0.2352
# Epoch 15/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.1803 - mean_absolute_error: 0.1899 - val_loss: 0.2476 - val_mean_absolute_error: 0.2345
# Epoch 16/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.1803 - mean_absolute_error: 0.1900 - val_loss: 0.2474 - val_mean_absolute_error: 0.2343
# Epoch 17/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.1803 - mean_absolute_error: 0.1899 - val_loss: 0.2531 - val_mean_absolute_error: 0.2375
# Epoch 18/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.1798 - mean_absolute_error: 0.1893 - val_loss: 0.2406 - val_mean_absolute_error: 0.2305
# Epoch 19/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.1531 - mean_absolute_error: 0.1743 - val_loss: 0.2285 - val_mean_absolute_error: 0.2243
# Epoch 20/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1504 - mean_absolute_error: 0.1723 - val_loss: 0.2196 - val_mean_absolute_error: 0.2194
# Epoch 21/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1498 - mean_absolute_error: 0.1716 - val_loss: 0.2148 - val_mean_absolute_error: 0.2167
# Epoch 22/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1496 - mean_absolute_error: 0.1714 - val_loss: 0.2115 - val_mean_absolute_error: 0.2147
# Epoch 23/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1496 - mean_absolute_error: 0.1713 - val_loss: 0.2102 - val_mean_absolute_error: 0.2142
# Epoch 24/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.1499 - mean_absolute_error: 0.1718 - val_loss: 0.2151 - val_mean_absolute_error: 0.2169
# Epoch 25/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.1494 - mean_absolute_error: 0.1712 - val_loss: 0.2071 - val_mean_absolute_error: 0.2124
# Epoch 26/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1491 - mean_absolute_error: 0.1710 - val_loss: 0.2079 - val_mean_absolute_error: 0.2129
# Epoch 27/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.1489 - mean_absolute_error: 0.1706 - val_loss: 0.2035 - val_mean_absolute_error: 0.2104
# Epoch 28/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1491 - mean_absolute_error: 0.1709 - val_loss: 0.2083 - val_mean_absolute_error: 0.2133
# Epoch 29/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.1492 - mean_absolute_error: 0.1710 - val_loss: 0.2028 - val_mean_absolute_error: 0.2100
# Epoch 30/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.1491 - mean_absolute_error: 0.1708 - val_loss: 0.1997 - val_mean_absolute_error: 0.2083
# Epoch 31/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.1493 - mean_absolute_error: 0.1712 - val_loss: 0.2023 - val_mean_absolute_error: 0.2097
# Epoch 32/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.1488 - mean_absolute_error: 0.1707 - val_loss: 0.1971 - val_mean_absolute_error: 0.2067
# Epoch 33/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.1490 - mean_absolute_error: 0.1708 - val_loss: 0.1995 - val_mean_absolute_error: 0.2082
# Epoch 34/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.1487 - mean_absolute_error: 0.1705 - val_loss: 0.2004 - val_mean_absolute_error: 0.2088
# Epoch 35/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1487 - mean_absolute_error: 0.1705 - val_loss: 0.2012 - val_mean_absolute_error: 0.2093
# Epoch 36/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.1484 - mean_absolute_error: 0.1702 - val_loss: 0.1981 - val_mean_absolute_error: 0.2075
# Epoch 37/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1485 - mean_absolute_error: 0.1704 - val_loss: 0.2024 - val_mean_absolute_error: 0.2102
# Epoch 38/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.1483 - mean_absolute_error: 0.1702 - val_loss: 0.2034 - val_mean_absolute_error: 0.2107
# Epoch 39/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.1482 - mean_absolute_error: 0.1702 - val_loss: 0.1988 - val_mean_absolute_error: 0.2080
# Epoch 40/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.1485 - mean_absolute_error: 0.1703 - val_loss: 0.1990 - val_mean_absolute_error: 0.2079
# Epoch 41/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1483 - mean_absolute_error: 0.1701 - val_loss: 0.1943 - val_mean_absolute_error: 0.2053
# Epoch 42/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.1481 - mean_absolute_error: 0.1697 - val_loss: 0.1952 - val_mean_absolute_error: 0.2059
# Epoch 43/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.1481 - mean_absolute_error: 0.1699 - val_loss: 0.1976 - val_mean_absolute_error: 0.2074
# Epoch 44/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.1485 - mean_absolute_error: 0.1701 - val_loss: 0.1937 - val_mean_absolute_error: 0.2052
# Epoch 45/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1482 - mean_absolute_error: 0.1699 - val_loss: 0.1926 - val_mean_absolute_error: 0.2044
# Epoch 46/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.1481 - mean_absolute_error: 0.1701 - val_loss: 0.1967 - val_mean_absolute_error: 0.2068
# Epoch 47/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.1479 - mean_absolute_error: 0.1697 - val_loss: 0.1984 - val_mean_absolute_error: 0.2078
# Epoch 48/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1480 - mean_absolute_error: 0.1698 - val_loss: 0.1895 - val_mean_absolute_error: 0.2023
# Epoch 49/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1477 - mean_absolute_error: 0.1696 - val_loss: 0.1978 - val_mean_absolute_error: 0.2075
# Epoch 50/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.1481 - mean_absolute_error: 0.1698 - val_loss: 0.1971 - val_mean_absolute_error: 0.2070
# Epoch 51/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1479 - mean_absolute_error: 0.1697 - val_loss: 0.1898 - val_mean_absolute_error: 0.2029
# Epoch 52/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1478 - mean_absolute_error: 0.1697 - val_loss: 0.1938 - val_mean_absolute_error: 0.2051
# Epoch 53/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1477 - mean_absolute_error: 0.1696 - val_loss: 0.1932 - val_mean_absolute_error: 0.2050
# Epoch 54/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.1477 - mean_absolute_error: 0.1695 - val_loss: 0.1938 - val_mean_absolute_error: 0.2053
# Epoch 55/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1477 - mean_absolute_error: 0.1695 - val_loss: 0.1964 - val_mean_absolute_error: 0.2068
# Epoch 56/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.1478 - mean_absolute_error: 0.1697 - val_loss: 0.1973 - val_mean_absolute_error: 0.2072
# Epoch 57/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.1474 - mean_absolute_error: 0.1692 - val_loss: 0.1914 - val_mean_absolute_error: 0.2038
# Epoch 58/100
# 113/114 [============================>.] - ETA: 0s - loss: 0.1475 - mean_absolute_error: 0.1694Restoring model weights from the end of the best epoch: 48.
# 114/114 [==============================] - 4s 33ms/step - loss: 0.1477 - mean_absolute_error: 0.1695 - val_loss: 0.1944 - val_mean_absolute_error: 0.2056
# Epoch 58: early stopping
# CPU times: user 6min 30s, sys: 28.4 s, total: 6min 58s
# Wall time: 3min 50s

# %%
# plot the losses
plt.figure(figsize = (15,7))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title("Learning curves for the losses")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# history.history['loss']

# %%
# plot the maes
plt.figure(figsize = (15,7))
plt.plot(history.history['mean_absolute_error'], label='Training MAE')
plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
plt.title("Learning curves for the MAE")
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %%
# Now unfreeze the last CNN layer
CNN_model.trainable = True

set_trainable = False

for layer in CNN_model.layers:
    if layer.name == 'conv2d_3':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

# %%
CNN_seq2seq_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 13, None, None, 3)   0         []
#                              ]
#
#  time_distributed (TimeDist  (None, 13, 32)               71808     ['input_1[0][0]']
#  ributed)
#
#  lstm (LSTM)                 [(None, 64),                 24832     ['time_distributed[0][0]']
#                               (None, 64),
#                               (None, 64)]
#
#  repeat_vector (RepeatVecto  (None, 7, 64)                0         ['lstm[0][0]']
#  r)
#
#  lstm_1 (LSTM)               (None, 7, 64)                33024     ['repeat_vector[0][0]',
#                                                                      'lstm[0][1]',
#                                                                      'lstm[0][2]']
#
#  time_distributed_1 (TimeDi  (None, 7, 32)                2080      ['lstm_1[0][0]']
#  stributed)
#
# ==================================================================================================
# Total params: 131744 (514.62 KB)
# Trainable params: 103104 (402.75 KB)
# Non-trainable params: 28640 (111.88 KB)
# __________________________________________________________________________________________________

# %%
# recompile and train the model

# %%
# compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.0009)
CNN_seq2seq_model.compile(loss='mean_squared_error', optimizer=opt, metrics = ['mean_absolute_error'])

# %%
# Early stopping
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', restore_best_weights = True, verbose=1, patience=10)

# %%
# %%time
# Train the model - Maybe we do not need a generator for now, let's see
history_new = CNN_seq2seq_model.fit(X_train, y_train, validation_data = (X_valid, y_valid), epochs = 100, callbacks = [es])
# Out:
# Epoch 1/100
# 2025-07-15 10:51:04.600912: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_2/time_distributed/model_1/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 114/114 [==============================] - 7s 39ms/step - loss: 0.1503 - mean_absolute_error: 0.1720 - val_loss: 0.1812 - val_mean_absolute_error: 0.1973
# Epoch 2/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1490 - mean_absolute_error: 0.1706 - val_loss: 0.1826 - val_mean_absolute_error: 0.1980
# Epoch 3/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1487 - mean_absolute_error: 0.1705 - val_loss: 0.1848 - val_mean_absolute_error: 0.1998
# Epoch 4/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1477 - mean_absolute_error: 0.1696 - val_loss: 0.1695 - val_mean_absolute_error: 0.1884
# Epoch 5/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1477 - mean_absolute_error: 0.1695 - val_loss: 0.1740 - val_mean_absolute_error: 0.1922
# Epoch 6/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.1471 - mean_absolute_error: 0.1691 - val_loss: 0.1736 - val_mean_absolute_error: 0.1916
# Epoch 7/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1466 - mean_absolute_error: 0.1683 - val_loss: 0.1732 - val_mean_absolute_error: 0.1920
# Epoch 8/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1455 - mean_absolute_error: 0.1675 - val_loss: 0.1799 - val_mean_absolute_error: 0.1967
# Epoch 9/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1454 - mean_absolute_error: 0.1673 - val_loss: 0.1744 - val_mean_absolute_error: 0.1931
# Epoch 10/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1451 - mean_absolute_error: 0.1670 - val_loss: 0.1717 - val_mean_absolute_error: 0.1907
# Epoch 11/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1448 - mean_absolute_error: 0.1668 - val_loss: 0.1688 - val_mean_absolute_error: 0.1885
# Epoch 12/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1446 - mean_absolute_error: 0.1667 - val_loss: 0.1705 - val_mean_absolute_error: 0.1903
# Epoch 13/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1443 - mean_absolute_error: 0.1664 - val_loss: 0.1605 - val_mean_absolute_error: 0.1816
# Epoch 14/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1450 - mean_absolute_error: 0.1671 - val_loss: 0.1585 - val_mean_absolute_error: 0.1800
# Epoch 15/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1441 - mean_absolute_error: 0.1660 - val_loss: 0.1702 - val_mean_absolute_error: 0.1901
# Epoch 16/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1437 - mean_absolute_error: 0.1658 - val_loss: 0.1642 - val_mean_absolute_error: 0.1851
# Epoch 17/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1431 - mean_absolute_error: 0.1653 - val_loss: 0.1629 - val_mean_absolute_error: 0.1844
# Epoch 18/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1433 - mean_absolute_error: 0.1655 - val_loss: 0.1588 - val_mean_absolute_error: 0.1804
# Epoch 19/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1432 - mean_absolute_error: 0.1653 - val_loss: 0.1613 - val_mean_absolute_error: 0.1827
# Epoch 20/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1428 - mean_absolute_error: 0.1650 - val_loss: 0.1670 - val_mean_absolute_error: 0.1876
# Epoch 21/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1427 - mean_absolute_error: 0.1648 - val_loss: 0.1598 - val_mean_absolute_error: 0.1815
# Epoch 22/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1424 - mean_absolute_error: 0.1647 - val_loss: 0.1584 - val_mean_absolute_error: 0.1805
# Epoch 23/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1415 - mean_absolute_error: 0.1638 - val_loss: 0.1623 - val_mean_absolute_error: 0.1834
# Epoch 24/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.1426 - mean_absolute_error: 0.1647 - val_loss: 0.1576 - val_mean_absolute_error: 0.1787
# Epoch 25/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.1260 - mean_absolute_error: 0.1571 - val_loss: 0.1137 - val_mean_absolute_error: 0.1630
# Epoch 26/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.0902 - mean_absolute_error: 0.1402 - val_loss: 0.1079 - val_mean_absolute_error: 0.1592
# Epoch 27/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0901 - mean_absolute_error: 0.1400 - val_loss: 0.1151 - val_mean_absolute_error: 0.1653
# Epoch 28/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0897 - mean_absolute_error: 0.1398 - val_loss: 0.1142 - val_mean_absolute_error: 0.1642
# Epoch 29/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0891 - mean_absolute_error: 0.1391 - val_loss: 0.1072 - val_mean_absolute_error: 0.1586
# Epoch 30/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0895 - mean_absolute_error: 0.1395 - val_loss: 0.1074 - val_mean_absolute_error: 0.1580
# Epoch 31/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0891 - mean_absolute_error: 0.1394 - val_loss: 0.1066 - val_mean_absolute_error: 0.1569
# Epoch 32/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0887 - mean_absolute_error: 0.1388 - val_loss: 0.1050 - val_mean_absolute_error: 0.1557
# Epoch 33/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0887 - mean_absolute_error: 0.1387 - val_loss: 0.1077 - val_mean_absolute_error: 0.1585
# Epoch 34/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0882 - mean_absolute_error: 0.1382 - val_loss: 0.1039 - val_mean_absolute_error: 0.1544
# Epoch 35/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0876 - mean_absolute_error: 0.1379 - val_loss: 0.1055 - val_mean_absolute_error: 0.1559
# Epoch 36/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0883 - mean_absolute_error: 0.1384 - val_loss: 0.1064 - val_mean_absolute_error: 0.1569
# Epoch 37/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0876 - mean_absolute_error: 0.1378 - val_loss: 0.1045 - val_mean_absolute_error: 0.1558
# Epoch 38/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.0876 - mean_absolute_error: 0.1378 - val_loss: 0.1034 - val_mean_absolute_error: 0.1541
# Epoch 39/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0867 - mean_absolute_error: 0.1367 - val_loss: 0.1111 - val_mean_absolute_error: 0.1613
# Epoch 40/100
# 114/114 [==============================] - 4s 35ms/step - loss: 0.0875 - mean_absolute_error: 0.1376 - val_loss: 0.1021 - val_mean_absolute_error: 0.1519
# Epoch 41/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0880 - mean_absolute_error: 0.1381 - val_loss: 0.1017 - val_mean_absolute_error: 0.1515
# Epoch 42/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0864 - mean_absolute_error: 0.1368 - val_loss: 0.1040 - val_mean_absolute_error: 0.1541
# Epoch 43/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.0867 - mean_absolute_error: 0.1369 - val_loss: 0.1091 - val_mean_absolute_error: 0.1581
# Epoch 44/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0863 - mean_absolute_error: 0.1364 - val_loss: 0.1073 - val_mean_absolute_error: 0.1583
# Epoch 45/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0866 - mean_absolute_error: 0.1367 - val_loss: 0.1088 - val_mean_absolute_error: 0.1572
# Epoch 46/100
# 114/114 [==============================] - 4s 33ms/step - loss: 0.0865 - mean_absolute_error: 0.1367 - val_loss: 0.1030 - val_mean_absolute_error: 0.1533
# Epoch 47/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0866 - mean_absolute_error: 0.1367 - val_loss: 0.1062 - val_mean_absolute_error: 0.1562
# Epoch 48/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0857 - mean_absolute_error: 0.1359 - val_loss: 0.1032 - val_mean_absolute_error: 0.1529
# Epoch 49/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0857 - mean_absolute_error: 0.1360 - val_loss: 0.1034 - val_mean_absolute_error: 0.1536
# Epoch 50/100
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0851 - mean_absolute_error: 0.1353 - val_loss: 0.1048 - val_mean_absolute_error: 0.1550
# Epoch 51/100
# 113/114 [============================>.] - ETA: 0s - loss: 0.0849 - mean_absolute_error: 0.1352Restoring model weights from the end of the best epoch: 41.
# 114/114 [==============================] - 4s 34ms/step - loss: 0.0850 - mean_absolute_error: 0.1353 - val_loss: 0.1109 - val_mean_absolute_error: 0.1597
# Epoch 51: early stopping
# CPU times: user 5min 42s, sys: 23.6 s, total: 6min 5s
# Wall time: 3min 21s

# %%
# save this model as keras?

# save this model
model_name_finetuned = 'CNN_seq2seq_non_overlapping.keras'
CNN_seq2seq_model.save('models' + '/' + model_name_finetuned)

# %%
# plot the losses
plt.figure(figsize = (15,7))
plt.plot(history_new.history['loss'], label='Training Loss')
plt.plot(history_new.history['val_loss'], label='Validation Loss')
plt.title("Learning curves for the losses")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# history.history['loss']

# %%
# plot the maes
plt.figure(figsize = (15,7))
plt.plot(history_new.history['mean_absolute_error'], label='Training MAE')
plt.plot(history_new.history['val_mean_absolute_error'], label='Validation MAE')
plt.title("Learning curves for the MAE")
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.show()
